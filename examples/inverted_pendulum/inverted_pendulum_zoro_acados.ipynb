# %%
import sys, os
sys.path += ["../../"]

import numpy as np
from scipy.stats import norm
import casadi as cas
from acados_template import AcadosOcp, AcadosSim, AcadosSimSolver, AcadosOcpSolver, AcadosOcpOptions
import matplotlib.pyplot as plt
import torch
import gpytorch

# zoRO imports
from zero_order_gpmpc import ZoroAcados
from inverted_pendulum_model_acados import export_simplependulum_ode_model, export_ocp_nominal
from utils import base_plot, add_plot_trajectory, EllipsoidTubeData2D

# gpytorch_utils
from gpytorch_utils.gp_hyperparam_training import generate_train_inputs_zoro, generate_train_outputs_at_inputs, train_gp_model
from gpytorch_utils.gp_utils import gp_data_from_model_and_path, gp_derivative_data_from_model_and_path, plot_gp_data, generate_grid_points
from gpytorch_utils.gp_model import MultitaskGPModel, BatchIndependentMultitaskGPModel

# %% [markdown]
# ## Define model parameters
#
# We model the inverted pendulum
#
# $$
# \dot{x} = f(x,u) = \begin{bmatrix} \dot{\theta} \\ \ddot{\theta} \end{bmatrix} = \begin{bmatrix} \dot{\theta} \\ -\sin(\theta) + u \end{bmatrix},
# $$
#
# which is to be controlled from the hanging-down resting position, $(\theta_0, \dot{\theta}_0) = (\pi, 0)$, to the upright position ($(\theta_r, \dot{\theta}_r) = (0,0)$), subject to the constraints that overshoot should be avoided, i.e.,
#
# $$
# \theta_{lb} \leq \theta \leq \theta_{ub}.
# $$
#
# The model setup and controller definition can be found in the functions `export_simplependulum_ode_model()`, `export_ocp_nominal()` in the `inverted_pendulum_model_acados.py` file.

# %%
# discretization
N = 30
T = 5
dT = T / N

# constraints
x0 = np.array([np.pi, 0])
nx = 2
nu = 1

# %% [markdown]
# ## Set up nominal solver

# %%
ocp_init = export_ocp_nominal(N,T,only_lower_bounds=True)
ocp_init.solver_options.nlp_solver_type = "SQP"

acados_ocp_init_solver = AcadosOcpSolver(ocp_init, json_file="acados_ocp_init_simplependulum_ode.json")
# Out:
# rm -f libacados_ocp_solver_simplependulum_ode.so
# rm -f simplependulum_ode_constraints/simplependulum_ode_constr_h_fun_jac_uxt_zt.o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun.o acados_solver_simplependulum_ode.o
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun_jac_uxt_zt.o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun.o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o acados_solver_simplependulum_ode.o acados_solver_simplependulum_ode.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-github/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.c
# cc -shared simplependulum_ode_constraints/simplependulum_ode_constr_h_fun_jac_uxt_zt.o simplependulum_ode_constraints/simplependulum_ode_constr_h_fun.o acados_solver_simplependulum_ode.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o -o libacados_ocp_solver_simplependulum_ode.so -L/home/amon/Repositories/zero-order-gp-mpc-github/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# acados was compiled without OpenMP.

# %% [markdown]
# ## Open-loop planning with nominal solver

# %%
# get initial values
X_init = np.zeros((N+1, nx))
U_init = np.zeros((N, nu))

# xcurrent = x0
X_init[0,:] = x0

# solve
status_init = acados_ocp_init_solver.solve()

if status_init != 0:
    raise Exception('acados acados_ocp_solver returned status {}. Exiting.'.format(status_init))

# get data
for i in range(N):
    X_init[i,:] = acados_ocp_init_solver.get(i, "x")
    U_init[i,:] = acados_ocp_init_solver.get(i, "u")

X_init[N,:] = acados_ocp_init_solver.get(N, "x")

# %% [markdown]
# ## Simulation results (nominal)

# %%
lb_theta = -ocp_init.constraints.lh[0]
fig, ax = base_plot(lb_theta=lb_theta)

plot_data_nom = EllipsoidTubeData2D(
    center_data = X_init,
    ellipsoid_data = None
)
add_plot_trajectory(ax, plot_data_nom, prob_tighten=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/inverted_pendulum_zoro_acados.ipynb Cell 9 line 8
#       <a href='vscode-notebook-cell:/home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/inverted_pendulum_zoro_acados.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> fig, ax = base_plot(lb_theta=lb_theta)
#       <a href='vscode-notebook-cell:/home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/inverted_pendulum_zoro_acados.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> plot_data_nom = EllipsoidTubeData2D(
#       <a href='vscode-notebook-cell:/home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/inverted_pendulum_zoro_acados.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>     center_data = X_init,
#       <a href='vscode-notebook-cell:/home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/inverted_pendulum_zoro_acados.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>     ellipsoid_data = None
#       <a href='vscode-notebook-cell:/home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/inverted_pendulum_zoro_acados.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> )
# ----> <a href='vscode-notebook-cell:/home/amon/Repositories/zero-order-gp-mpc-github/examples/inverted_pendulum/inverted_pendulum_zoro_acados.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> add_plot_trajectory(ax, plot_data_nom, prob_tighten=prob_tighten)
#
# NameError: name 'prob_tighten' is not defined

# %% [markdown]
# ## Robustify simulation
#
# Now we consider the inverted pendulum subject to process noise, i.e., after discretization,
#
# $$
# x_{k+1} = F(x_k, u_k) + w_k,
# $$
#
# where $w_k \sim \mathcal{N}(0, \Sigma_w)$ denotes process noise and we jhave a potentially nois initial condition $x_0 \sim \mathcal{N}(0, \Sigma_{x0})$ (defined below). Constraints should now be satisfied with satisfaction probability $p_x$, i.e.,
#
# $$
# \mathrm{Pr}(h(x,u) \leq 0) \geq p_x.
# $$
#
# Note that currently zoRO only accepts upper bounds, i.e., we need to reformulate the nominal constraints $\theta \leq \theta_{ub}$, $-\theta \leq -\theta_{lb}$.
# Afterwards, we consider the tightened constraints
#
# $$
# h(x,u) + \alpha \sqrt{C(x,u) P C(x,u)} \leq 0,
# $$
#
# see problem definition https://www.sciencedirect.com/science/article/pii/S0947358023000912, eq. (9).

# %%
# satisfaction probability for chance constraints
prob_x = 0.9
prob_tighten = norm.ppf(prob_x)

# noise
# uncertainty dynamics
sigma_theta = (0.0001/360.) * 2 * np.pi
sigma_omega = (0.0001/360.) * 2 * np.pi
w_theta = 0.03
w_omega = 0.03
Sigma_x0 = np.array([
    [sigma_theta**2,0],
    [0,sigma_omega**2]
])
Sigma_W = np.array([
    [w_theta**2, 0],
    [0, w_omega**2]
])

# %% [markdown]
# ### Nominal OCP with lower bounds

# %%
# without gp model
ocp_zoro_nogp = export_ocp_nominal(N, T, only_lower_bounds=True)

# OCP is discretized inside zoRO solver, so we need to choose DISCRETE integration here
ocp_zoro_nogp.solver_options.integrator_type = "DISCRETE"
ocp_zoro_nogp.solver_options.qp_solver = "PARTIAL_CONDENSING_HPIPM"
ocp_zoro_nogp.solver_options.hessian_approx = "GAUSS_NEWTON"
ocp_zoro_nogp.solver_options.nlp_solver_type = "SQP_RTI"

# %% [markdown]
# ### Nominal model with lower bounds
#
# The tightenings $\sqrt{\ldots}$ can thereby be automatically defined using the `tighten_model_constraints()` function.

# %%
# zoro_solver_nogp = ZoroAcados(ocp_zoro_nogp, sim, prob_x, Sigma_x0, Sigma_W+Sigma_GP_prior)
from zero_order_gpmpc.zoro_acados_utils import generate_h_tightening_funs_SX, only_upper_bounds_expr, tighten_model_constraints

# make constraints one-sided
ocp_model = export_simplependulum_ode_model(only_lower_bounds=True)

# tighten constraints
idh_tight = np.array([0]) # lower constraint on theta (theta >= 0)

ocp_model_tightened, h_jac_x_fun, h_tighten_fun, h_tighten_jac_x_fun, h_tighten_jac_sig_fun = tighten_model_constraints(ocp_model, idh_tight, prob_x)

ocp_zoro_nogp.model = ocp_model_tightened
ocp_zoro_nogp.dims.nh = ocp_model_tightened.con_h_expr.shape[0]
ocp_zoro_nogp.dims.np = ocp_model_tightened.p.shape[0]
ocp_zoro_nogp.parameter_values = np.zeros((ocp_zoro_nogp.dims.np,))
# Out:
# CasADi - 2023-12-12 14:15:54 MESSAGE("calling "gcc -O3 -fPIC -c jit_tmpb765fh.c -o ./tmp_casadi_compiler_shellx9azkq.o"") [.../casadi/solvers/shell_compiler.cpp:232]
# CasADi - 2023-12-12 14:15:54 MESSAGE("calling "gcc ./tmp_casadi_compiler_shellx9azkq.o -o ./tmp_casadi_compiler_shellx9azkq.so -shared"") [.../casadi/solvers/shell_compiler.cpp:251]
# CasADi - 2023-12-12 14:15:54 MESSAGE("calling "gcc -O3 -fPIC -c jit_tmp4agkhu.c -o ./tmp_casadi_compiler_shellf03i4d.o"") [.../casadi/solvers/shell_compiler.cpp:232]
# CasADi - 2023-12-12 14:15:54 MESSAGE("calling "gcc ./tmp_casadi_compiler_shellf03i4d.o -o ./tmp_casadi_compiler_shellf03i4d.so -shared"") [.../casadi/solvers/shell_compiler.cpp:251]
# CasADi - 2023-12-12 14:15:54 MESSAGE("calling "gcc -O3 -fPIC -c jit_tmpm1l5iz.c -o ./tmp_casadi_compiler_shellt9t7e9.o"") [.../casadi/solvers/shell_compiler.cpp:232]
# CasADi - 2023-12-12 14:15:54 MESSAGE("calling "gcc ./tmp_casadi_compiler_shellt9t7e9.o -o ./tmp_casadi_compiler_shellt9t7e9.so -shared"") [.../casadi/solvers/shell_compiler.cpp:251]
# CasADi - 2023-12-12 14:15:54 MESSAGE("calling "gcc -O3 -fPIC -c jit_tmpno8wnq.c -o ./tmp_casadi_compiler_shell2mfkyb.o"") [.../casadi/solvers/shell_compiler.cpp:232]
# CasADi - 2023-12-12 14:15:54 MESSAGE("calling "gcc ./tmp_casadi_compiler_shell2mfkyb.o -o ./tmp_casadi_compiler_shell2mfkyb.so -shared"") [.../casadi/solvers/shell_compiler.cpp:251]

# %% [markdown]
# ## Simulator object
#
# To automatically discretize the model (and obtain sensitivities of the discrete-time model) within the zero-order implementation, we create the `AcadosSimSolver` object to pass to the solver.

# %%
# integrator for nominal model
sim = AcadosSim()

sim.model = ocp_zoro_nogp.model
sim.parameter_values = ocp_zoro_nogp.parameter_values
sim.solver_options.integrator_type = "ERK"

# set prediction horizon
sim.solver_options.T = dT

# acados_ocp_solver = AcadosOcpSolver(ocp_init, json_file = 'acados_ocp_' + model.name + '.json')
acados_integrator = AcadosSimSolver(sim, json_file = 'acados_sim_' + sim.model.name + '.json')
# Out:
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode.o acados_sim_solver_simplependulum_ode.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode.so -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %% [markdown]
# ## Create zero-order solver (without GP)
#
# Everything comes together in the `ZoroAcados` constructor:
#
# - nominal OCP `ocp_zoro_nogp`,
# - simulator `AcadosSim` object `sim`,
# - satisfaction probability `prob_x`,
# - initial uncertainty `Sigma_x0`,
# - process noise `Sigma_W`,
# - Jacobian of tightened constraints w.r.t. covariances $P$, `h_tighten_jac_sig_fun`

# %%
# solve with zoRO (no GP model, only process noise)
zoro_solver_nogp = ZoroAcados(
    ocp_zoro_nogp, sim, prob_x, Sigma_x0, Sigma_W, 
    h_tightening_jac_sig_fun=h_tighten_jac_sig_fun
)

for i in range(N):
    zoro_solver_nogp.ocp_solver.set(i, "x",X_init[i,:])
    zoro_solver_nogp.ocp_solver.set(i, "u",U_init[i,:])
zoro_solver_nogp.ocp_solver.set(N, "x",X_init[N,:])

zoro_solver_nogp.solve()
X_nogp,U_nogp,P_nogp = zoro_solver_nogp.get_solution()
# Out:
# make: *** No rule to make target 'clean_all'.  Stop.
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o acados_solver_linear_model_with_params_nx2_nu1_np3.o acados_solver_linear_model_with_params_nx2_nu1_np3.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.c
# cc -shared linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o acados_solver_linear_model_with_params_nx2_nu1_np3.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o -o libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# cython \
# -o acados_ocp_solver_pyx.c \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template \
# /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template/acados_ocp_solver_pyx.pyx \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code \
#
# cc  -c -O2 \
# -fPIC \
# -o acados_ocp_solver_pyx.o \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include \
# -I /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include \
# -I /home/amon/.pyenv/versions/3.9.13/include/python3.9 \
# acados_ocp_solver_pyx.c \
# In file included from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from acados_ocp_solver_pyx.c:1157:
# /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# cc  -shared \
# -o acados_ocp_solver_pyx.so \
# -Wl,-rpath=/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib \
# acados_ocp_solver_pyx.o \
# /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code/libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so \
# -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm
# rm -f libacados_sim_solver_simplependulum_ode.so
# rm -f acados_sim_solver_simplependulum_ode.o
# rm -f acados_sim_solver_pyx.so
# rm -f acados_sim_solver_pyx.o
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode.o acados_sim_solver_simplependulum_ode.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode.so -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm
# cython \
# -o acados_sim_solver_pyx.c \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template \
# /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template/acados_sim_solver_pyx.pyx \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code \
#
# cc  -c -O2 \
# -fPIC \
# -o acados_sim_solver_pyx.o \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include \
# -I /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include \
# -I /home/amon/.pyenv/versions/3.9.13/include/python3.9 \
# acados_sim_solver_pyx.c \
# In file included from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from acados_sim_solver_pyx.c:1157:
# /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# cc  -shared \
# -o acados_sim_solver_pyx.so \
# -Wl,-rpath=/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib \
# acados_sim_solver_pyx.o \
# /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code/libacados_sim_solver_simplependulum_ode.so \
# -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm
# residuals after  0 SQP_RTI iterations:
#  [2.61799388e+00 3.21205793e-02 4.83119264e-01 1.00000314e-10]
# residuals after  1 SQP_RTI iterations:
#  [8.38750017e-02 4.19534323e-03 1.18992166e-01 1.00000314e-10]
# residuals after  2 SQP_RTI iterations:
#  [9.37869994e-03 9.30640690e-05 3.82469401e-02 1.00000314e-10]
# residuals after  3 SQP_RTI iterations:
#  [2.33955768e-03 9.49542084e-06 2.90535563e-02 1.00000314e-10]
# residuals after  4 SQP_RTI iterations:
#  [4.82024890e-04 1.52568919e-06 2.52456927e-03 1.00000314e-10]
# residuals after  5 SQP_RTI iterations:
#  [1.28396364e-05 8.24297507e-09 1.25390807e-03 1.00000314e-10]
# residuals after  6 SQP_RTI iterations:
#  [1.19849386e-05 3.83184920e-09 2.07504972e-05 1.00000314e-10]
# residuals after  7 SQP_RTI iterations:
#  [1.20355070e-06 1.40630563e-12 2.81161999e-05 1.00000314e-10]
# residuals after  8 SQP_RTI iterations:
#  [2.15258928e-07 2.32398822e-12 3.22504250e-06 1.00000314e-10]
# residuals after  9 SQP_RTI iterations:
#  [4.07048809e-08 2.41473508e-14 2.31507085e-07 1.00000314e-10]

# %% [markdown]
# ### Plot open-loop prediction
#
# Ellipsoids denote the Gaussian confidence intervals, note that one (terminal) ellipsoid "sticks out" since we have omitted the terminal constraint here.

# %%
fig, ax = base_plot(lb_theta=lb_theta)

plot_data_nogp = EllipsoidTubeData2D(
    center_data = X_nogp,
    ellipsoid_data = np.array(P_nogp)
    # ellipsoid_data = None
)
add_plot_trajectory(ax, plot_data_nom, color_fun=plt.cm.Blues, prob_tighten=prob_tighten)
add_plot_trajectory(ax, plot_data_nogp, color_fun=plt.cm.Oranges, prob_tighten=prob_tighten)

# %% [markdown]
# # GP training
#
# We use a model with different parameters to emulate the real-world model and obtain some training data. Also create simulator object for real-world model to evaluate our results later (not used in solver).

# %%
# generate training data for GP with augmented model

# "real model"
model_actual = export_simplependulum_ode_model()
model_actual.f_expl_expr = model_actual.f_expl_expr + cas.vertcat(
    cas.DM(0),
    -0.5*cas.sin((model_actual.x[0])**2)
)
model_actual.f_impl_expr = model_actual.xdot - model_actual.f_expl_expr
model_actual.name = model_actual.name + "_actual"

# acados integrator
sim_actual = AcadosSim()
sim_actual.model = model_actual
sim_actual.solver_options.integrator_type = "ERK"

# set prediction horizon
sim_actual.solver_options.T = dT

# acados_ocp_solver = AcadosOcpSolver(ocp, json_file = 'acados_ocp_' + model.name + '.json')
acados_integrator_actual = AcadosSimSolver(sim_actual, json_file = 'acados_sim_' + model_actual.name + '.json')
# Out:
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode_actual.o acados_sim_solver_simplependulum_ode_actual.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_ode_fun.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_forw.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_adj.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode_actual.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_ode_fun.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_forw.o simplependulum_ode_actual_model/simplependulum_ode_actual_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode_actual.so -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %% [markdown]
# ## Generate training data
#
# We generate training data (one-step ahead residuals `y_train` for starting point `x_train`) here by running robustified (cautious) solver without GP.

# %%
random_seed = 123
N_sim_per_x0 = 1
N_x0 = 10
x0_rand_scale = 0.1

x_train, x0_arr = generate_train_inputs_zoro(
    zoro_solver_nogp, 
    x0, 
    N_sim_per_x0, 
    N_x0, 
    random_seed=random_seed, 
    x0_rand_scale=x0_rand_scale
)

y_train = generate_train_outputs_at_inputs(
    x_train, 
    acados_integrator, 
    acados_integrator_actual, 
    Sigma_W
)
# Out:
# residuals after  0 SQP_RTI iterations:
#  [3.16675886e-09 4.44089210e-16 4.27721330e-02 1.00000318e-10]
# residuals after  1 SQP_RTI iterations:
#  [1.81841412e-03 7.39588958e-06 2.66030228e-03 1.00000318e-10]
# residuals after  2 SQP_RTI iterations:
#  [2.85033004e-04 7.59306090e-08 1.40610077e-03 1.00000318e-10]
# residuals after  3 SQP_RTI iterations:
#  [7.24845112e-05 7.52988734e-09 8.56199689e-04 1.00000318e-10]
# residuals after  4 SQP_RTI iterations:
#  [1.48982036e-05 1.23030214e-09 7.01648263e-05 1.00000318e-10]
# residuals after  5 SQP_RTI iterations:
#  [4.64019629e-07 5.34579325e-12 3.86534300e-05 1.00000318e-10]
# residuals after  6 SQP_RTI iterations:
#  [3.81938348e-07 3.57902596e-12 5.65328833e-07 1.00000318e-10]
# residuals after  0 SQP_RTI iterations:
#  [3.61811785e-08 1.22124533e-15 2.02588728e-01 6.55186561e-09]
# residuals after  1 SQP_RTI iterations:
#  [1.88273708e-02 3.21718618e-04 2.90150871e-02 1.00000309e-10]
# residuals after  2 SQP_RTI iterations:
#  [2.57363035e-03 6.44205698e-06 1.14193492e-02 1.00000309e-10]
# residuals after  3 SQP_RTI iterations:
#  [6.04113867e-04 6.27837967e-07 7.24946898e-03 1.00000309e-10]
# residuals after  4 SQP_RTI iterations:
#  [1.27345175e-04 9.25422469e-08 5.91679765e-04 1.00000309e-10]
# residuals after  5 SQP_RTI iterations:
#  [3.45363385e-06 4.19302759e-10 3.12567452e-04 1.00000309e-10]
# residuals after  6 SQP_RTI iterations:
#  [3.11195632e-06 2.37469766e-10 5.02565525e-06 1.00000309e-10]
# residuals after  7 SQP_RTI iterations:
#  [2.96465168e-07 8.22397705e-14 7.07316834e-06 1.00000309e-10]
# residuals after  8 SQP_RTI iterations:
#  [5.37147216e-08 1.45786161e-13 7.80398668e-07 1.00000309e-10]
# residuals after  0 SQP_RTI iterations:
#  [1.01948054e-08 1.47104551e-15 3.49552158e-01 1.00000319e-10]
# residuals after  1 SQP_RTI iterations:
#  [2.93775854e-02 7.22342091e-04 3.56357873e-02 1.00000319e-10]
# residuals after  2 SQP_RTI iterations:
#  [3.95971339e-03 1.42269407e-05 1.72094123e-02 1.00000319e-10]
# residuals after  3 SQP_RTI iterations:
#  [9.59351739e-04 1.36872316e-06 1.20073059e-02 1.00000319e-10]
# residuals after  4 SQP_RTI iterations:
#  [2.05211910e-04 2.44315832e-07 9.33778547e-04 1.00000319e-10]
# residuals after  5 SQP_RTI iterations:
#  [5.09331502e-06 9.12281917e-10 5.40449758e-04 1.00000319e-10]
# residuals after  6 SQP_RTI iterations:
#  [5.15410274e-06 6.98794272e-10 1.09689529e-05 1.00000319e-10]
# residuals after  7 SQP_RTI iterations:
#  [5.25291064e-07 2.92529889e-13 1.22800570e-05 1.00000319e-10]
# residuals after  8 SQP_RTI iterations:
#  [9.39952498e-08 4.41105485e-13 1.44700768e-06 1.00000319e-10]
# residuals after  9 SQP_RTI iterations:
#  [1.77363568e-08 4.87110352e-15 9.68839426e-08 1.00000319e-10]
# residuals after  0 SQP_RTI iterations:
#  [1.48718970e-09 4.44089210e-16 4.74557358e-01 1.29232956e-09]
# residuals after  1 SQP_RTI iterations:
#  [3.65045832e-02 9.81494791e-04 5.17821947e-02 1.00000324e-10]
# residuals after  2 SQP_RTI iterations:
#  [4.81625238e-03 2.34691846e-05 1.81488292e-02 1.00000324e-10]
# residuals after  3 SQP_RTI iterations:
#  [1.41391726e-03 2.33968991e-06 1.70348530e-02 1.00000324e-10]
# residuals after  4 SQP_RTI iterations:
#  [3.09708418e-04 4.86305680e-07 1.40513130e-03 1.00000324e-10]
# residuals after  5 SQP_RTI iterations:
#  [1.36978869e-05 2.03911010e-09 8.39419928e-04 1.00000324e-10]
# residuals after  6 SQP_RTI iterations:
#  [1.05739087e-05 1.59142040e-09 1.93368522e-05 1.00000324e-10]
# residuals after  7 SQP_RTI iterations:
#  [9.19555264e-07 7.79445952e-13 2.34814975e-05 1.00000324e-10]
# residuals after  8 SQP_RTI iterations:
#  [1.90902140e-07 1.41640866e-12 3.11887321e-06 1.00000324e-10]
# residuals after  9 SQP_RTI iterations:
#  [5.01744651e-08 2.08028039e-14 2.93581258e-07 1.00000324e-10]
# residuals after  0 SQP_RTI iterations:
#  [2.43755682e-09 2.91433544e-16 7.86795994e-01 1.00000314e-10]
# residuals after  1 SQP_RTI iterations:
#  [5.48474861e-02 2.29292529e-03 8.58562401e-02 1.00000314e-10]
# residuals after  2 SQP_RTI iterations:
#  [7.71719098e-03 5.63857154e-05 2.83875498e-02 7.17353204e-09]
# residuals after  3 SQP_RTI iterations:
#  [1.67405615e-03 5.10227405e-06 2.16076585e-02 1.00000314e-10]
# residuals after  4 SQP_RTI iterations:
#  [3.74471646e-04 8.18891191e-07 1.57241756e-03 1.00000314e-10]
# residuals after  5 SQP_RTI iterations:
#  [9.10202953e-06 3.00043439e-09 9.26612706e-04 1.00000314e-10]
# residuals after  6 SQP_RTI iterations:
#  [8.95088377e-06 2.07899384e-09 2.24818359e-05 1.00000314e-10]
# residuals after  7 SQP_RTI iterations:
#  [9.38095908e-07 1.08101722e-12 2.04049044e-05 1.00000314e-10]
# residuals after  8 SQP_RTI iterations:
#  [1.56013932e-07 1.22375721e-12 2.47377985e-06 1.00000314e-10]
# residuals after  9 SQP_RTI iterations:
#  [3.03810247e-08 1.45855550e-14 1.60512553e-07 1.00000314e-10]
# residuals after  0 SQP_RTI iterations:
#  [2.37045839e-09 4.44089210e-16 1.87670095e-01 1.00000312e-10]
# residuals after  1 SQP_RTI iterations:
#  [1.02049848e-02 7.65271825e-05 1.30251474e-02 1.00000312e-10]
# residuals after  2 SQP_RTI iterations:
#  [1.26801845e-03 1.52205796e-06 5.13717460e-03 1.00000312e-10]
# residuals after  3 SQP_RTI iterations:
#  [2.95471981e-04 1.43860434e-07 3.74793706e-03 1.00000312e-10]
# residuals after  4 SQP_RTI iterations:
#  [6.34615693e-05 2.44040186e-08 2.91492205e-04 1.00000312e-10]
# residuals after  5 SQP_RTI iterations:
#  [1.47734641e-06 9.81844467e-11 1.64420221e-04 1.00000312e-10]
# residuals after  6 SQP_RTI iterations:
#  [1.57102966e-06 6.50698800e-11 3.43966425e-06 1.00000312e-10]
# residuals after  7 SQP_RTI iterations:
#  [1.60101431e-07 2.85743651e-14 3.68693630e-06 1.00000312e-10]
# residuals after  8 SQP_RTI iterations:
#  [2.81527406e-08 3.97598621e-14 4.35424904e-07 1.00000312e-10]
# residuals after  0 SQP_RTI iterations:
#  [5.35673361e-09 4.57966998e-16 5.47329622e-01 1.75425913e-09]
# residuals after  1 SQP_RTI iterations:
#  [3.37673513e-02 8.49078673e-04 5.02160190e-02 1.00000313e-10]
# residuals after  2 SQP_RTI iterations:
#  [4.24161881e-03 1.70750865e-05 1.75580936e-02 7.04867479e-09]
# residuals after  3 SQP_RTI iterations:
#  [9.40450836e-04 1.62712696e-06 1.11246216e-02 1.00000313e-10]
# residuals after  4 SQP_RTI iterations:
#  [2.18535101e-04 2.24502178e-07 8.65052875e-04 1.02977949e-10]
# residuals after  5 SQP_RTI iterations:
#  [4.45940823e-06 9.74288872e-10 4.76103100e-04 1.37501779e-10]
# residuals after  6 SQP_RTI iterations:
#  [6.32584902e-06 5.45907444e-10 1.42890448e-05 1.37643909e-10]
# residuals after  7 SQP_RTI iterations:
#  [5.68422802e-07 4.05397937e-13 1.19850420e-05 1.36586173e-10]
# residuals after  8 SQP_RTI iterations:
#  [1.09540519e-07 3.87398447e-13 1.58854098e-06 1.36470139e-10]
# residuals after  9 SQP_RTI iterations:
#  [2.71597519e-08 5.95357097e-15 1.56752421e-07 1.36486111e-10]
# residuals after  0 SQP_RTI iterations:
#  [1.25349686e-09 4.44089210e-16 5.98544793e-01 1.00000313e-10]
# residuals after  1 SQP_RTI iterations:
#  [3.85400996e-02 1.13826234e-03 4.58414266e-02 1.00000313e-10]
# residuals after  2 SQP_RTI iterations:
#  [4.78621983e-03 2.16146247e-05 2.10943372e-02 1.00000313e-10]
# residuals after  3 SQP_RTI iterations:
#  [1.17286066e-03 2.12010215e-06 1.45645891e-02 1.00000313e-10]
# residuals after  4 SQP_RTI iterations:
#  [2.46362061e-04 3.63448189e-07 1.17198494e-03 1.00000313e-10]
# residuals after  5 SQP_RTI iterations:
#  [6.56432767e-06 1.50016215e-09 6.49152807e-04 1.00000313e-10]
# residuals after  6 SQP_RTI iterations:
#  [6.21519627e-06 1.01094909e-09 1.18577503e-05 1.00000313e-10]
# residuals after  7 SQP_RTI iterations:
#  [6.17448936e-07 3.83845733e-13 1.47810127e-05 1.00000313e-10]
# residuals after  8 SQP_RTI iterations:
#  [1.12776452e-07 6.37101483e-13 1.70149419e-06 1.00000313e-10]
# residuals after  9 SQP_RTI iterations:
#  [2.11665958e-08 6.73072709e-15 1.22686374e-07 1.00000313e-10]
# residuals after  0 SQP_RTI iterations:
#  [1.66245884e-09 4.44089210e-16 7.49202704e-01 1.38954619e-09]
# residuals after  1 SQP_RTI iterations:
#  [5.06149466e-02 1.99830980e-03 8.08919607e-02 1.00000308e-10]
# residuals after  2 SQP_RTI iterations:
#  [6.23984586e-03 3.97595992e-05 2.82974166e-02 1.00000308e-10]
# residuals after  3 SQP_RTI iterations:
#  [1.34078710e-03 3.86923243e-06 1.58510855e-02 1.81171243e-09]
# residuals after  4 SQP_RTI iterations:
#  [3.13115575e-04 4.67396411e-07 1.25328637e-03 2.43792241e-09]
# residuals after  5 SQP_RTI iterations:
#  [6.51290906e-06 2.16747995e-09 6.57723557e-04 2.80744129e-09]
# residuals after  6 SQP_RTI iterations:
#  [8.92598974e-06 1.05974764e-09 1.88599383e-05 2.82542923e-09]
# residuals after  7 SQP_RTI iterations:
#  [7.77728013e-07 7.22581717e-13 1.63678033e-05 2.81660682e-09]
# residuals after  8 SQP_RTI iterations:
#  [1.55503019e-07 7.29916128e-13 2.11544047e-06 2.81520762e-09]
# residuals after  9 SQP_RTI iterations:
#  [3.69906602e-08 1.07275300e-14 2.18381569e-07 2.81529573e-09]
# residuals after  0 SQP_RTI iterations:
#  [1.73274906e-09 2.22044605e-16 6.59376569e-01 1.00000315e-10]
# residuals after  1 SQP_RTI iterations:
#  [4.84451304e-02 1.89806682e-03 5.50735448e-02 1.00000315e-10]
# residuals after  2 SQP_RTI iterations:
#  [6.07730890e-03 3.43879009e-05 2.77786386e-02 1.00000315e-10]
# residuals after  3 SQP_RTI iterations:
#  [1.49299353e-03 3.36861370e-06 1.82690798e-02 1.00000315e-10]
# residuals after  4 SQP_RTI iterations:
#  [3.12897776e-04 5.69496656e-07 1.47722275e-03 1.00000315e-10]
# residuals after  5 SQP_RTI iterations:
#  [8.47397913e-06 2.32774096e-09 8.17847603e-04 1.00000315e-10]
# residuals after  6 SQP_RTI iterations:
#  [7.90368452e-06 1.60478685e-09 1.46009675e-05 1.00000315e-10]
# residuals after  7 SQP_RTI iterations:
#  [7.81977555e-07 5.98604499e-13 1.86633642e-05 1.00000315e-10]
# residuals after  8 SQP_RTI iterations:
#  [1.42410815e-07 1.01572917e-12 2.13624584e-06 1.00000315e-10]
# residuals after  9 SQP_RTI iterations:
#  [2.68315894e-08 1.06165077e-14 1.57063798e-07 1.00000315e-10]

# %% [markdown]
# ## Hyper-parameter training for GP model
#
# Optimize hyper-parameters of GP model (kernel function parameters, ...)

# %%
x_train_tensor = torch.Tensor(x_train)
y_train_tensor = torch.Tensor(y_train)
nout = y_train.shape[1]

likelihood = gpytorch.likelihoods.MultitaskGaussianLikelihood(
    num_tasks = nout
)
gp_model = BatchIndependentMultitaskGPModel(x_train_tensor, y_train_tensor, likelihood, nout)

# %%
training_iterations = 500
rng_seed = 456

gp_model, likelihood = train_gp_model(gp_model, torch_seed=rng_seed, training_iterations=training_iterations)

# EVAL MODE
gp_model.eval()
likelihood.eval()
# Out:
# Iter 1/500 - Loss: 1.462
# Iter 2/500 - Loss: 1.424
# Iter 3/500 - Loss: 1.386
# Iter 4/500 - Loss: 1.347
# Iter 5/500 - Loss: 1.307
# Iter 6/500 - Loss: 1.267
# Iter 7/500 - Loss: 1.225
# Iter 8/500 - Loss: 1.184
# Iter 9/500 - Loss: 1.141
# Iter 10/500 - Loss: 1.098
# Iter 11/500 - Loss: 1.054
# Iter 12/500 - Loss: 1.010
# Iter 13/500 - Loss: 0.964
# Iter 14/500 - Loss: 0.919
# Iter 15/500 - Loss: 0.873
# Iter 16/500 - Loss: 0.826
# Iter 17/500 - Loss: 0.779
# Iter 18/500 - Loss: 0.731
# Iter 19/500 - Loss: 0.683
# Iter 20/500 - Loss: 0.635
# Iter 21/500 - Loss: 0.586
# Iter 22/500 - Loss: 0.536
# Iter 23/500 - Loss: 0.487
# Iter 24/500 - Loss: 0.437
# Iter 25/500 - Loss: 0.387
# Iter 26/500 - Loss: 0.336
# Iter 27/500 - Loss: 0.286
# Iter 28/500 - Loss: 0.235
# Iter 29/500 - Loss: 0.184
# Iter 30/500 - Loss: 0.133
# Iter 31/500 - Loss: 0.082
# Iter 32/500 - Loss: 0.030
# Iter 33/500 - Loss: -0.021
# Iter 34/500 - Loss: -0.073
# Iter 35/500 - Loss: -0.124
# Iter 36/500 - Loss: -0.176
# Iter 37/500 - Loss: -0.227
# Iter 38/500 - Loss: -0.278
# Iter 39/500 - Loss: -0.330
# Iter 40/500 - Loss: -0.381
# Iter 41/500 - Loss: -0.432
# Iter 42/500 - Loss: -0.483
# Iter 43/500 - Loss: -0.534
# Iter 44/500 - Loss: -0.584
# Iter 45/500 - Loss: -0.635
# Iter 46/500 - Loss: -0.685
# Iter 47/500 - Loss: -0.734
# Iter 48/500 - Loss: -0.784
# Iter 49/500 - Loss: -0.833
# Iter 50/500 - Loss: -0.881
# Iter 51/500 - Loss: -0.929
# Iter 52/500 - Loss: -0.977
# Iter 53/500 - Loss: -1.023
# Iter 54/500 - Loss: -1.070
# Iter 55/500 - Loss: -1.115
# Iter 56/500 - Loss: -1.160
# Iter 57/500 - Loss: -1.204
# Iter 58/500 - Loss: -1.247
# Iter 59/500 - Loss: -1.289
# Iter 60/500 - Loss: -1.330
# Iter 61/500 - Loss: -1.370
# Iter 62/500 - Loss: -1.409
# Iter 63/500 - Loss: -1.446
# Iter 64/500 - Loss: -1.483
# Iter 65/500 - Loss: -1.518
# Iter 66/500 - Loss: -1.552
# Iter 67/500 - Loss: -1.584
# Iter 68/500 - Loss: -1.616
# Iter 69/500 - Loss: -1.646
# Iter 70/500 - Loss: -1.676
# Iter 71/500 - Loss: -1.704
# Iter 72/500 - Loss: -1.732
# Iter 73/500 - Loss: -1.760
# Iter 74/500 - Loss: -1.786
# Iter 75/500 - Loss: -1.812
# Iter 76/500 - Loss: -1.837
# Iter 77/500 - Loss: -1.860
# Iter 78/500 - Loss: -1.882
# Iter 79/500 - Loss: -1.901
# Iter 80/500 - Loss: -1.918
# Iter 81/500 - Loss: -1.932
# Iter 82/500 - Loss: -1.945
# Iter 83/500 - Loss: -1.956
# Iter 84/500 - Loss: -1.965
# Iter 85/500 - Loss: -1.974
# Iter 86/500 - Loss: -1.981
# Iter 87/500 - Loss: -1.988
# Iter 88/500 - Loss: -1.995
# Iter 89/500 - Loss: -2.001
# Iter 90/500 - Loss: -2.006
# Iter 91/500 - Loss: -2.011
# Iter 92/500 - Loss: -2.016
# Iter 93/500 - Loss: -2.019
# Iter 94/500 - Loss: -2.023
# Iter 95/500 - Loss: -2.025
# Iter 96/500 - Loss: -2.028
# Iter 97/500 - Loss: -2.029
# Iter 98/500 - Loss: -2.030
# Iter 99/500 - Loss: -2.031
# Iter 100/500 - Loss: -2.032
# Iter 101/500 - Loss: -2.033
# Iter 102/500 - Loss: -2.033
# Iter 103/500 - Loss: -2.033
# Iter 104/500 - Loss: -2.034
# Iter 105/500 - Loss: -2.034
# Iter 106/500 - Loss: -2.035
# Iter 107/500 - Loss: -2.035
# Iter 108/500 - Loss: -2.036
# Iter 109/500 - Loss: -2.036
# Iter 110/500 - Loss: -2.036
# Iter 111/500 - Loss: -2.036
# Iter 112/500 - Loss: -2.036
# Iter 113/500 - Loss: -2.036
# Iter 114/500 - Loss: -2.036
# Iter 115/500 - Loss: -2.036
# Iter 116/500 - Loss: -2.036
# Iter 117/500 - Loss: -2.036
# Iter 118/500 - Loss: -2.036
# Iter 119/500 - Loss: -2.037
# Iter 120/500 - Loss: -2.037
# Iter 121/500 - Loss: -2.037
# Iter 122/500 - Loss: -2.037
# Iter 123/500 - Loss: -2.037
# Iter 124/500 - Loss: -2.037
# Iter 125/500 - Loss: -2.037
# Iter 126/500 - Loss: -2.037
# Iter 127/500 - Loss: -2.037
# Iter 128/500 - Loss: -2.037
# Iter 129/500 - Loss: -2.037
# Iter 130/500 - Loss: -2.038
# Iter 131/500 - Loss: -2.038
# Iter 132/500 - Loss: -2.038
# Iter 133/500 - Loss: -2.038
# Iter 134/500 - Loss: -2.038
# Iter 135/500 - Loss: -2.038
# Iter 136/500 - Loss: -2.038
# Iter 137/500 - Loss: -2.038
# Iter 138/500 - Loss: -2.038
# Iter 139/500 - Loss: -2.038
# Iter 140/500 - Loss: -2.038
# Iter 141/500 - Loss: -2.038
# Iter 142/500 - Loss: -2.038
# Iter 143/500 - Loss: -2.038
# Iter 144/500 - Loss: -2.038
# Iter 145/500 - Loss: -2.039
# Iter 146/500 - Loss: -2.039
# Iter 147/500 - Loss: -2.039
# Iter 148/500 - Loss: -2.039
# Iter 149/500 - Loss: -2.039
# Iter 150/500 - Loss: -2.039
# Iter 151/500 - Loss: -2.039
# Iter 152/500 - Loss: -2.039
# Iter 153/500 - Loss: -2.039
# Iter 154/500 - Loss: -2.039
# Iter 155/500 - Loss: -2.039
# Iter 156/500 - Loss: -2.039
# Iter 157/500 - Loss: -2.039
# Iter 158/500 - Loss: -2.039
# Iter 159/500 - Loss: -2.039
# Iter 160/500 - Loss: -2.039
# Iter 161/500 - Loss: -2.039
# Iter 162/500 - Loss: -2.039
# Iter 163/500 - Loss: -2.039
# Iter 164/500 - Loss: -2.039
# Iter 165/500 - Loss: -2.039
# Iter 166/500 - Loss: -2.039
# Iter 167/500 - Loss: -2.039
# Iter 168/500 - Loss: -2.039
# Iter 169/500 - Loss: -2.039
# Iter 170/500 - Loss: -2.039
# Iter 171/500 - Loss: -2.039
# Iter 172/500 - Loss: -2.039
# Iter 173/500 - Loss: -2.039
# Iter 174/500 - Loss: -2.039
# Iter 175/500 - Loss: -2.039
# Iter 176/500 - Loss: -2.039
# Iter 177/500 - Loss: -2.039
# Iter 178/500 - Loss: -2.039
# Iter 179/500 - Loss: -2.039
# Iter 180/500 - Loss: -2.039
# Iter 181/500 - Loss: -2.039
# Iter 182/500 - Loss: -2.039
# Iter 183/500 - Loss: -2.039
# Iter 184/500 - Loss: -2.039
# Iter 185/500 - Loss: -2.039
# Iter 186/500 - Loss: -2.039
# Iter 187/500 - Loss: -2.039
# Iter 188/500 - Loss: -2.039
# Iter 189/500 - Loss: -2.039
# Iter 190/500 - Loss: -2.039
# Iter 191/500 - Loss: -2.039
# Iter 192/500 - Loss: -2.039
# Iter 193/500 - Loss: -2.039
# Iter 194/500 - Loss: -2.039
# Iter 195/500 - Loss: -2.039
# Iter 196/500 - Loss: -2.039
# Iter 197/500 - Loss: -2.039
# Iter 198/500 - Loss: -2.039
# Iter 199/500 - Loss: -2.039
# Iter 200/500 - Loss: -2.039
# Iter 201/500 - Loss: -2.039
# Iter 202/500 - Loss: -2.039
# Iter 203/500 - Loss: -2.039
# Iter 204/500 - Loss: -2.039
# Iter 205/500 - Loss: -2.040
# Iter 206/500 - Loss: -2.040
# Iter 207/500 - Loss: -2.040
# Iter 208/500 - Loss: -2.040
# Iter 209/500 - Loss: -2.040
# Iter 210/500 - Loss: -2.040
# Iter 211/500 - Loss: -2.040
# Iter 212/500 - Loss: -2.040
# Iter 213/500 - Loss: -2.040
# Iter 214/500 - Loss: -2.040
# Iter 215/500 - Loss: -2.040
# Iter 216/500 - Loss: -2.040
# Iter 217/500 - Loss: -2.040
# Iter 218/500 - Loss: -2.040
# Iter 219/500 - Loss: -2.040
# Iter 220/500 - Loss: -2.040
# Iter 221/500 - Loss: -2.040
# Iter 222/500 - Loss: -2.040
# Iter 223/500 - Loss: -2.040
# Iter 224/500 - Loss: -2.040
# Iter 225/500 - Loss: -2.040
# Iter 226/500 - Loss: -2.040
# Iter 227/500 - Loss: -2.040
# Iter 228/500 - Loss: -2.040
# Iter 229/500 - Loss: -2.040
# Iter 230/500 - Loss: -2.040
# Iter 231/500 - Loss: -2.040
# Iter 232/500 - Loss: -2.040
# Iter 233/500 - Loss: -2.040
# Iter 234/500 - Loss: -2.040
# Iter 235/500 - Loss: -2.040
# Iter 236/500 - Loss: -2.040
# Iter 237/500 - Loss: -2.040
# Iter 238/500 - Loss: -2.040
# Iter 239/500 - Loss: -2.040
# Iter 240/500 - Loss: -2.040
# Iter 241/500 - Loss: -2.040
# Iter 242/500 - Loss: -2.040
# Iter 243/500 - Loss: -2.040
# Iter 244/500 - Loss: -2.040
# Iter 245/500 - Loss: -2.040
# Iter 246/500 - Loss: -2.040
# Iter 247/500 - Loss: -2.040
# Iter 248/500 - Loss: -2.040
# Iter 249/500 - Loss: -2.040
# Iter 250/500 - Loss: -2.040
# Iter 251/500 - Loss: -2.040
# Iter 252/500 - Loss: -2.040
# Iter 253/500 - Loss: -2.040
# Iter 254/500 - Loss: -2.040
# Iter 255/500 - Loss: -2.040
# Iter 256/500 - Loss: -2.040
# Iter 257/500 - Loss: -2.040
# Iter 258/500 - Loss: -2.040
# Iter 259/500 - Loss: -2.040
# Iter 260/500 - Loss: -2.040
# Iter 261/500 - Loss: -2.040
# Iter 262/500 - Loss: -2.040
# Iter 263/500 - Loss: -2.040
# Iter 264/500 - Loss: -2.040
# Iter 265/500 - Loss: -2.040
# Iter 266/500 - Loss: -2.040
# Iter 267/500 - Loss: -2.040
# Iter 268/500 - Loss: -2.040
# Iter 269/500 - Loss: -2.040
# Iter 270/500 - Loss: -2.040
# Iter 271/500 - Loss: -2.040
# Iter 272/500 - Loss: -2.040
# Iter 273/500 - Loss: -2.040
# Iter 274/500 - Loss: -2.040
# Iter 275/500 - Loss: -2.040
# Iter 276/500 - Loss: -2.040
# Iter 277/500 - Loss: -2.040
# Iter 278/500 - Loss: -2.040
# Iter 279/500 - Loss: -2.040
# Iter 280/500 - Loss: -2.040
# Iter 281/500 - Loss: -2.040
# Iter 282/500 - Loss: -2.040
# Iter 283/500 - Loss: -2.040
# Iter 284/500 - Loss: -2.040
# Iter 285/500 - Loss: -2.040
# Iter 286/500 - Loss: -2.040
# Iter 287/500 - Loss: -2.040
# Iter 288/500 - Loss: -2.040
# Iter 289/500 - Loss: -2.040
# Iter 290/500 - Loss: -2.040
# Iter 291/500 - Loss: -2.040
# Iter 292/500 - Loss: -2.040
# Iter 293/500 - Loss: -2.040
# Iter 294/500 - Loss: -2.040
# Iter 295/500 - Loss: -2.040
# Iter 296/500 - Loss: -2.040
# Iter 297/500 - Loss: -2.040
# Iter 298/500 - Loss: -2.040
# Iter 299/500 - Loss: -2.040
# Iter 300/500 - Loss: -2.040
# Iter 301/500 - Loss: -2.040
# Iter 302/500 - Loss: -2.040
# Iter 303/500 - Loss: -2.040
# Iter 304/500 - Loss: -2.040
# Iter 305/500 - Loss: -2.040
# Iter 306/500 - Loss: -2.040
# Iter 307/500 - Loss: -2.040
# Iter 308/500 - Loss: -2.040
# Iter 309/500 - Loss: -2.040
# Iter 310/500 - Loss: -2.040
# Iter 311/500 - Loss: -2.040
# Iter 312/500 - Loss: -2.040
# Iter 313/500 - Loss: -2.040
# Iter 314/500 - Loss: -2.040
# Iter 315/500 - Loss: -2.040
# Iter 316/500 - Loss: -2.040
# Iter 317/500 - Loss: -2.040
# Iter 318/500 - Loss: -2.040
# Iter 319/500 - Loss: -2.040
# Iter 320/500 - Loss: -2.040
# Iter 321/500 - Loss: -2.040
# Iter 322/500 - Loss: -2.040
# Iter 323/500 - Loss: -2.040
# Iter 324/500 - Loss: -2.040
# Iter 325/500 - Loss: -2.040
# Iter 326/500 - Loss: -2.040
# Iter 327/500 - Loss: -2.040
# Iter 328/500 - Loss: -2.040
# Iter 329/500 - Loss: -2.040
# Iter 330/500 - Loss: -2.040
# Iter 331/500 - Loss: -2.040
# Iter 332/500 - Loss: -2.040
# Iter 333/500 - Loss: -2.040
# Iter 334/500 - Loss: -2.040
# Iter 335/500 - Loss: -2.040
# Iter 336/500 - Loss: -2.040
# Iter 337/500 - Loss: -2.040
# Iter 338/500 - Loss: -2.040
# Iter 339/500 - Loss: -2.040
# Iter 340/500 - Loss: -2.040
# Iter 341/500 - Loss: -2.040
# Iter 342/500 - Loss: -2.040
# Iter 343/500 - Loss: -2.040
# Iter 344/500 - Loss: -2.040
# Iter 345/500 - Loss: -2.040
# Iter 346/500 - Loss: -2.040
# Iter 347/500 - Loss: -2.040
# Iter 348/500 - Loss: -2.040
# Iter 349/500 - Loss: -2.040
# Iter 350/500 - Loss: -2.040
# Iter 351/500 - Loss: -2.040
# Iter 352/500 - Loss: -2.040
# Iter 353/500 - Loss: -2.040
# Iter 354/500 - Loss: -2.040
# Iter 355/500 - Loss: -2.040
# Iter 356/500 - Loss: -2.040
# Iter 357/500 - Loss: -2.040
# Iter 358/500 - Loss: -2.040
# Iter 359/500 - Loss: -2.040
# Iter 360/500 - Loss: -2.040
# Iter 361/500 - Loss: -2.040
# Iter 362/500 - Loss: -2.040
# Iter 363/500 - Loss: -2.040
# Iter 364/500 - Loss: -2.040
# Iter 365/500 - Loss: -2.040
# Iter 366/500 - Loss: -2.040
# Iter 367/500 - Loss: -2.040
# Iter 368/500 - Loss: -2.040
# Iter 369/500 - Loss: -2.040
# Iter 370/500 - Loss: -2.040
# Iter 371/500 - Loss: -2.040
# Iter 372/500 - Loss: -2.040
# Iter 373/500 - Loss: -2.040
# Iter 374/500 - Loss: -2.040
# Iter 375/500 - Loss: -2.040
# Iter 376/500 - Loss: -2.040
# Iter 377/500 - Loss: -2.040
# Iter 378/500 - Loss: -2.040
# Iter 379/500 - Loss: -2.040
# Iter 380/500 - Loss: -2.040
# Iter 381/500 - Loss: -2.040
# Iter 382/500 - Loss: -2.040
# Iter 383/500 - Loss: -2.040
# Iter 384/500 - Loss: -2.040
# Iter 385/500 - Loss: -2.040
# Iter 386/500 - Loss: -2.040
# Iter 387/500 - Loss: -2.040
# Iter 388/500 - Loss: -2.040
# Iter 389/500 - Loss: -2.040
# Iter 390/500 - Loss: -2.040
# Iter 391/500 - Loss: -2.040
# Iter 392/500 - Loss: -2.040
# Iter 393/500 - Loss: -2.040
# Iter 394/500 - Loss: -2.040
# Iter 395/500 - Loss: -2.040
# Iter 396/500 - Loss: -2.040
# Iter 397/500 - Loss: -2.040
# Iter 398/500 - Loss: -2.040
# Iter 399/500 - Loss: -2.040
# Iter 400/500 - Loss: -2.040
# Iter 401/500 - Loss: -2.040
# Iter 402/500 - Loss: -2.040
# Iter 403/500 - Loss: -2.040
# Iter 404/500 - Loss: -2.040
# Iter 405/500 - Loss: -2.040
# Iter 406/500 - Loss: -2.040
# Iter 407/500 - Loss: -2.040
# Iter 408/500 - Loss: -2.040
# Iter 409/500 - Loss: -2.040
# Iter 410/500 - Loss: -2.040
# Iter 411/500 - Loss: -2.040
# Iter 412/500 - Loss: -2.040
# Iter 413/500 - Loss: -2.040
# Iter 414/500 - Loss: -2.040
# Iter 415/500 - Loss: -2.040
# Iter 416/500 - Loss: -2.040
# Iter 417/500 - Loss: -2.040
# Iter 418/500 - Loss: -2.040
# Iter 419/500 - Loss: -2.040
# Iter 420/500 - Loss: -2.040
# Iter 421/500 - Loss: -2.040
# Iter 422/500 - Loss: -2.040
# Iter 423/500 - Loss: -2.040
# Iter 424/500 - Loss: -2.040
# Iter 425/500 - Loss: -2.040
# Iter 426/500 - Loss: -2.040
# Iter 427/500 - Loss: -2.040
# Iter 428/500 - Loss: -2.040
# Iter 429/500 - Loss: -2.040
# Iter 430/500 - Loss: -2.040
# Iter 431/500 - Loss: -2.040
# Iter 432/500 - Loss: -2.040
# Iter 433/500 - Loss: -2.040
# Iter 434/500 - Loss: -2.040
# Iter 435/500 - Loss: -2.040
# Iter 436/500 - Loss: -2.040
# Iter 437/500 - Loss: -2.040
# Iter 438/500 - Loss: -2.040
# Iter 439/500 - Loss: -2.040
# Iter 440/500 - Loss: -2.040
# Iter 441/500 - Loss: -2.040
# Iter 442/500 - Loss: -2.040
# Iter 443/500 - Loss: -2.040
# Iter 444/500 - Loss: -2.040
# Iter 445/500 - Loss: -2.040
# Iter 446/500 - Loss: -2.040
# Iter 447/500 - Loss: -2.040
# Iter 448/500 - Loss: -2.040
# Iter 449/500 - Loss: -2.040
# Iter 450/500 - Loss: -2.040
# Iter 451/500 - Loss: -2.040
# Iter 452/500 - Loss: -2.040
# Iter 453/500 - Loss: -2.040
# Iter 454/500 - Loss: -2.040
# Iter 455/500 - Loss: -2.040
# Iter 456/500 - Loss: -2.040
# Iter 457/500 - Loss: -2.040
# Iter 458/500 - Loss: -2.040
# Iter 459/500 - Loss: -2.040
# Iter 460/500 - Loss: -2.040
# Iter 461/500 - Loss: -2.040
# Iter 462/500 - Loss: -2.040
# Iter 463/500 - Loss: -2.040
# Iter 464/500 - Loss: -2.040
# Iter 465/500 - Loss: -2.040
# Iter 466/500 - Loss: -2.040
# Iter 467/500 - Loss: -2.040
# Iter 468/500 - Loss: -2.040
# Iter 469/500 - Loss: -2.040
# Iter 470/500 - Loss: -2.040
# Iter 471/500 - Loss: -2.040
# Iter 472/500 - Loss: -2.040
# Iter 473/500 - Loss: -2.040
# Iter 474/500 - Loss: -2.040
# Iter 475/500 - Loss: -2.040
# Iter 476/500 - Loss: -2.040
# Iter 477/500 - Loss: -2.040
# Iter 478/500 - Loss: -2.040
# Iter 479/500 - Loss: -2.040
# Iter 480/500 - Loss: -2.040
# Iter 481/500 - Loss: -2.040
# Iter 482/500 - Loss: -2.040
# Iter 483/500 - Loss: -2.040
# Iter 484/500 - Loss: -2.040
# Iter 485/500 - Loss: -2.040
# Iter 486/500 - Loss: -2.040
# Iter 487/500 - Loss: -2.040
# Iter 488/500 - Loss: -2.040
# Iter 489/500 - Loss: -2.040
# Iter 490/500 - Loss: -2.040
# Iter 491/500 - Loss: -2.040
# Iter 492/500 - Loss: -2.040
# Iter 493/500 - Loss: -2.040
# Iter 494/500 - Loss: -2.040
# Iter 495/500 - Loss: -2.040
# Iter 496/500 - Loss: -2.040
# Iter 497/500 - Loss: -2.040
# Iter 498/500 - Loss: -2.040
# Iter 499/500 - Loss: -2.040
# Iter 500/500 - Loss: -2.040
# MultitaskGaussianLikelihood(
#   (raw_task_noises_constraint): GreaterThan(1.000E-04)
#   (raw_noise_constraint): GreaterThan(1.000E-04)
# )

# %% [markdown]
# ## Plot GP predictions
#
# We plot GP predictions along the predicted trajectory of the robustified solver by projecting the multivariate plot down to a line.

# %%
num_samples = 5
use_likelihood = False

num_points_between_samples = 30
t_lin = np.linspace(0,1,num_points_between_samples,endpoint=False)

x_plot_waypts = np.hstack((
    X_nogp[1:,:],
    U_nogp
)) 
x_plot = []
for i in range(x_plot_waypts.shape[0]-1):
    x_plot += [x_plot_waypts[i,:] + (x_plot_waypts[i+1,:] - x_plot_waypts[i,:]) * t for t in t_lin]
x_plot = np.vstack(x_plot)

gp_data = gp_data_from_model_and_path(gp_model, likelihood, x_plot, num_samples=num_samples, use_likelihood=use_likelihood)
plot_gp_data([gp_data], marker_size_lim=[1, 15])
# Out:
# /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/gpytorch/distributions/multivariate_normal.py:319: NumericalWarning: Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-06.
#   warnings.warn(
# (<Figure size 800x600 with 2 Axes>,
#  array([<Axes: title={'center': 'Observed Values (Likelihood), output 0'}>,
#         <Axes: title={'center': 'Observed Values (Likelihood), output 1'}>],
#        dtype=object))

# %% [markdown]
# We can also plot the derivative of the GP. Note that the projected Jacobian is not smooth since our path is not smooth either (jump projection direction = jump in Jacobian); however, the actual Jacobian should be smooth here (squared exponential kernel).

# %%
gp_derivative_data = gp_derivative_data_from_model_and_path(gp_model, likelihood, x_plot, num_samples=0)
plot_gp_data([gp_derivative_data], marker_size_lim=[5, 20], plot_train_data=False)
# Out:
# (<Figure size 800x600 with 2 Axes>,
#  array([<Axes: title={'center': 'Observed Values (Likelihood), output 0'}>,
#         <Axes: title={'center': 'Observed Values (Likelihood), output 1'}>],
#        dtype=object))

# %% [markdown]
# Compare with plotting along a slice of the dimension. Since we generated training data along the path of the robustified controller, the GP looks pretty untrained along a slice of the coordinates.

# %%
# plot along axis
x_dim_lims = np.array([
    [0, np.pi],
    [-2, 1],
    [-2, 2]
    ])
x_dim_slice = np.array([
    1 * np.pi,
    0,
    0
])
x_dim_plot = 2
x_grid = generate_grid_points(x_dim_lims, x_dim_slice, x_dim_plot, num_points=800)

gp_grid_data = gp_data_from_model_and_path(gp_model, likelihood, x_grid, num_samples=num_samples, use_likelihood=use_likelihood)
fig, ax = plot_gp_data([gp_grid_data], marker_size_lim=[5, 50])

y_lim_0 = ax[0].get_ylim()
y_lim_1 = ax[1].get_ylim()

# %% [markdown]
# Jacobian... not much going on away from the data points (this is good!)

# %%
gp_derivative_grid_data = gp_derivative_data_from_model_and_path(gp_model, likelihood, x_grid, num_samples=0)
fig, ax = plot_gp_data([gp_derivative_grid_data], marker_size_lim=[5, 50], plot_train_data=False)

ax[0].set_ylim(*y_lim_0)
ax[1].set_ylim(*y_lim_1)
plt.draw()

# %% [markdown]
# # Zero-Order GP-MPC
#
# We can add the GP model to the solver by simply adding it as an argument to the `ZoroAcados` function. Therefore we copy (important!) the robustified controller and then instantiate another solver object.

# %%
from copy import deepcopy
ocp_zoro = deepcopy(ocp_zoro_nogp)

zoro_solver = ZoroAcados(
    ocp_zoro, sim, prob_x, Sigma_x0, Sigma_W, 
    h_tightening_jac_sig_fun=h_tighten_jac_sig_fun, 
    gp_model=gp_model
)

for i in range(N):
    zoro_solver.ocp_solver.set(i, "x",X_init[i,:])
    zoro_solver.ocp_solver.set(i, "u",U_init[i,:])
zoro_solver.ocp_solver.set(N, "x",X_init[N,:])

zoro_solver.solve()
X,U,P = zoro_solver.get_solution()
# Out:
# make: *** No rule to make target 'clean_all'.  Stop.
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o acados_solver_linear_model_with_params_nx2_nu1_np3.o acados_solver_linear_model_with_params_nx2_nu1_np3.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.c
# cc -shared linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o acados_solver_linear_model_with_params_nx2_nu1_np3.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o -o libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# cython \
# -o acados_ocp_solver_pyx.c \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template \
# /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template/acados_ocp_solver_pyx.pyx \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code \
#
# cc  -c -O2 \
# -fPIC \
# -o acados_ocp_solver_pyx.o \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include \
# -I /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include \
# -I /home/amon/.pyenv/versions/3.9.13/include/python3.9 \
# acados_ocp_solver_pyx.c \
# In file included from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from acados_ocp_solver_pyx.c:1157:
# /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# cc  -shared \
# -o acados_ocp_solver_pyx.so \
# -Wl,-rpath=/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib \
# acados_ocp_solver_pyx.o \
# /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code/libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so \
# -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm
# rm -f libacados_sim_solver_simplependulum_ode.so
# rm -f acados_sim_solver_simplependulum_ode.o
# rm -f acados_sim_solver_pyx.so
# rm -f acados_sim_solver_pyx.o
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode.o acados_sim_solver_simplependulum_ode.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode.so -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm
# cython \
# -o acados_sim_solver_pyx.c \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template \
# /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template/acados_sim_solver_pyx.pyx \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code \
#
# cc  -c -O2 \
# -fPIC \
# -o acados_sim_solver_pyx.o \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include \
# -I /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include \
# -I /home/amon/.pyenv/versions/3.9.13/include/python3.9 \
# acados_sim_solver_pyx.c \
# In file included from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from acados_sim_solver_pyx.c:1157:
# /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# cc  -shared \
# -o acados_sim_solver_pyx.so \
# -Wl,-rpath=/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib \
# acados_sim_solver_pyx.o \
# /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code/libacados_sim_solver_simplependulum_ode.so \
# -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm
# /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/gpytorch/distributions/multivariate_normal.py:319: NumericalWarning: Negative variance values detected. This is likely due to numerical instabilities. Rounding negative variances up to 1e-06.
#   warnings.warn(
# residuals after  0 SQP_RTI iterations:
#  [2.61799388e+00 9.91316869e-02 8.71978073e-01 5.90334273e-09]
# residuals after  1 SQP_RTI iterations:
#  [6.09967197e-01 3.12521767e-02 4.46797290e-01 4.43322697e-10]
# residuals after  2 SQP_RTI iterations:
#  [1.28942773e-01 3.50197265e-03 4.38614531e-01 1.00000314e-10]
# residuals after  3 SQP_RTI iterations:
#  [2.06804169e-02 2.01091760e-03 3.06702087e-01 5.97092663e-10]
# residuals after  4 SQP_RTI iterations:
#  [2.10781524e-02 7.27047891e-04 8.57975677e-02 1.00000314e-10]
# residuals after  5 SQP_RTI iterations:
#  [1.21499835e-02 5.78677114e-05 2.35688360e-02 1.00000314e-10]
# residuals after  6 SQP_RTI iterations:
#  [4.78392708e-03 1.61567805e-05 2.48082484e-02 5.13644857e-09]
# residuals after  7 SQP_RTI iterations:
#  [3.96364050e-03 1.16000575e-05 1.03208088e-02 8.17889750e-10]
# residuals after  8 SQP_RTI iterations:
#  [2.06960501e-03 3.39842695e-06 6.33489402e-03 2.65213956e-10]
# residuals after  9 SQP_RTI iterations:
#  [1.28121150e-03 1.05186357e-06 4.40017214e-03 3.06600186e-10]
# residuals after  10 SQP_RTI iterations:
#  [8.92195533e-04 1.50129199e-06 2.58113364e-03 3.52522966e-10]
# residuals after  11 SQP_RTI iterations:
#  [5.19099155e-04 9.76026058e-07 1.62973591e-03 4.02867206e-10]
# residuals after  12 SQP_RTI iterations:
#  [3.30311675e-04 9.32158854e-07 1.05310738e-03 3.95608961e-10]
# residuals after  13 SQP_RTI iterations:
#  [2.14215602e-04 9.18671301e-07 6.26081621e-04 3.94234274e-10]
# residuals after  14 SQP_RTI iterations:
#  [1.27816630e-04 1.12901133e-06 3.87982690e-04 3.87494762e-10]
# residuals after  15 SQP_RTI iterations:
#  [7.92127754e-05 8.30017119e-07 2.35657013e-04 3.88672567e-10]
# residuals after  16 SQP_RTI iterations:
#  [4.67076504e-05 1.34241445e-06 1.45436946e-04 3.87609289e-10]
# residuals after  17 SQP_RTI iterations:
#  [2.83189968e-05 1.34882923e-06 1.14844931e-04 3.89742743e-10]
# residuals after  18 SQP_RTI iterations:
#  [2.35231863e-05 1.43210950e-06 8.28305233e-05 3.89149413e-10]
# residuals after  19 SQP_RTI iterations:
#  [1.68094497e-05 1.07260507e-06 5.31074133e-05 3.89199327e-10]
# residuals after  20 SQP_RTI iterations:
#  [1.17356702e-05 8.30115863e-07 4.99280389e-05 3.88904039e-10]
# residuals after  21 SQP_RTI iterations:
#  [1.87610465e-05 1.14694952e-06 4.03472951e-05 3.88796352e-10]
# residuals after  22 SQP_RTI iterations:
#  [2.42786264e-05 1.26149192e-06 1.09872045e-05 3.88591668e-10]
# residuals after  23 SQP_RTI iterations:
#  [9.93208616e-06 1.35592606e-06 1.38384820e-05 3.90141258e-10]
# residuals after  24 SQP_RTI iterations:
#  [6.17547361e-06 1.13995151e-06 1.66772716e-05 3.88443066e-10]
# residuals after  25 SQP_RTI iterations:
#  [9.91537000e-06 1.02916022e-06 1.51541587e-05 3.88886673e-10]
# residuals after  26 SQP_RTI iterations:
#  [6.06975988e-06 8.77432120e-07 2.61942958e-05 3.89176746e-10]
# residuals after  27 SQP_RTI iterations:
#  [7.82228640e-06 1.37401270e-06 1.08780817e-05 3.88755060e-10]
# residuals after  28 SQP_RTI iterations:
#  [8.09982818e-06 8.15838576e-07 1.48713056e-05 3.89651727e-10]
# residuals after  29 SQP_RTI iterations:
#  [1.29616500e-05 1.67265534e-06 2.46754242e-05 3.89095092e-10]

# %% [markdown]
# ## Trained GP vs. no GP
#
# Plotting trained GP against no-GP, we see that the GP-MPC controller still has higher uncertainties than the robustified one. This is because the GP covariance, albeit being small where data points are, is *added* to the process noise, i.e., we make the controller even more cautious.

# %%
fig, ax = base_plot(lb_theta=lb_theta)

plot_data_gp = EllipsoidTubeData2D(
    center_data = X,
    ellipsoid_data = np.array(P)
    # ellipsoid_data = None
)
add_plot_trajectory(ax, plot_data_nogp, color_fun=plt.cm.Oranges)
add_plot_trajectory(ax, plot_data_gp, color_fun=plt.cm.Reds)

# %% [markdown]
# We can get a more insightful comparison by comparing the *conditioned* GP (i.e., with optimized hyper-parameters and data), to the *unconditioned* GP (i.e., with the same, optimized hyper-parameters and no data).
#
# As you can see, the hyper-parameter optimization also provides us with an estimate of the measurement noise for the data points, which corersponds to added process noise in our model (epistemic uncertainty).

# %%
ocp_zoro_gpprior = deepcopy(ocp_zoro_nogp)

gp_model.eval()
y_test = torch.Tensor(np.array([[1,1,1]]))
Sigma_GP_prior = gp_model.covar_module(y_test).numpy()

Sigma_GP_prior = np.diag(Sigma_GP_prior.flatten())
Sigma_GP_prior
# Out:
# array([[3.8452441e-07, 0.0000000e+00],
#        [0.0000000e+00, 3.5683976e-03]], dtype=float32)

# %%
Sigma_W
# Out:
# array([[0.0009, 0.    ],
#        [0.    , 0.0009]])

# %% [markdown]
# Especially in the velocity component, this really makes a difference!

# %%
Sigma_W+Sigma_GP_prior
# Out:
# array([[0.00090038, 0.        ],
#        [0.        , 0.0044684 ]])

# %% [markdown]
# Now we solve again with *unconditioned* GP and compare...

# %%
# zoro_solver_gpprior = ZoroAcados(ocp_zoro_gpprior, sim, prob_x, Sigma_x0, Sigma_W+Sigma_GP_prior)
zoro_solver_gpprior = ZoroAcados(
    ocp_zoro_gpprior, sim, prob_x, Sigma_x0, Sigma_W+Sigma_GP_prior, 
    h_tightening_jac_sig_fun=h_tighten_jac_sig_fun
)

for i in range(N):
    zoro_solver_gpprior.ocp_solver.set(i, "x",X_init[i,:])
    zoro_solver_gpprior.ocp_solver.set(i, "u",U_init[i,:])
zoro_solver_gpprior.ocp_solver.set(N, "x",X_init[N,:])
# Out:
# make: *** No rule to make target 'clean_all'.  Stop.
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o acados_solver_linear_model_with_params_nx2_nu1_np3.o acados_solver_linear_model_with_params_nx2_nu1_np3.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.c
# cc -shared linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun_jac_uxt_zt.o linear_model_with_params_nx2_nu1_np3_constraints/linear_model_with_params_nx2_nu1_np3_constr_h_fun.o acados_solver_linear_model_with_params_nx2_nu1_np3.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun.o linear_model_with_params_nx2_nu1_np3_model/linear_model_with_params_nx2_nu1_np3_dyn_disc_phi_fun_jac.o -o libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm \
# -L -l
# cython \
# -o acados_ocp_solver_pyx.c \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template \
# /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template/acados_ocp_solver_pyx.pyx \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code \
#
# cc  -c -O2 \
# -fPIC \
# -o acados_ocp_solver_pyx.o \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include \
# -I /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include \
# -I /home/amon/.pyenv/versions/3.9.13/include/python3.9 \
# acados_ocp_solver_pyx.c \
# In file included from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from acados_ocp_solver_pyx.c:1157:
# /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# cc  -shared \
# -o acados_ocp_solver_pyx.so \
# -Wl,-rpath=/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib \
# acados_ocp_solver_pyx.o \
# /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code/libacados_ocp_solver_linear_model_with_params_nx2_nu1_np3.so \
# -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm
# rm -f libacados_sim_solver_simplependulum_ode.so
# rm -f acados_sim_solver_simplependulum_ode.o
# rm -f acados_sim_solver_pyx.so
# rm -f acados_sim_solver_pyx.o
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o acados_sim_solver_simplependulum_ode.o acados_sim_solver_simplependulum_ode.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/acados -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include -I/home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include  -c -o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.c
# cc -shared acados_sim_solver_simplependulum_ode.o simplependulum_ode_model/simplependulum_ode_expl_ode_fun.o simplependulum_ode_model/simplependulum_ode_expl_vde_forw.o simplependulum_ode_model/simplependulum_ode_expl_vde_adj.o -o libacados_sim_solver_simplependulum_ode.so -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm
# cython \
# -o acados_sim_solver_pyx.c \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template \
# /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/../interfaces/acados_template/acados_template/acados_sim_solver_pyx.pyx \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code \
#
# cc  -c -O2 \
# -fPIC \
# -o acados_sim_solver_pyx.o \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/blasfeo/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include/hpipm/include/ \
# -I /home/amon/Repositories/zero-order-gp-mpc-package/acados/include \
# -I /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include \
# -I /home/amon/.pyenv/versions/3.9.13/include/python3.9 \
# acados_sim_solver_pyx.c \
# In file included from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from acados_sim_solver_pyx.c:1157:
# /home/amon/.local/share/virtualenvs/zero-order-gp-mpc-package-2g3NboO-/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# cc  -shared \
# -o acados_sim_solver_pyx.so \
# -Wl,-rpath=/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib \
# acados_sim_solver_pyx.o \
# /home/amon/Repositories/zero-order-gp-mpc-package/examples/inverted_pendulum/c_generated_code/libacados_sim_solver_simplependulum_ode.so \
# -L/home/amon/Repositories/zero-order-gp-mpc-package/acados/lib -lacados -lhpipm -lblasfeo -lm

# %%
zoro_solver_gpprior.solve()

X_gpprior,U_gpprior,P_gpprior = zoro_solver_gpprior.get_solution()
# Out:
# residuals after  0 SQP_RTI iterations:
#  [2.61799388e+00 3.21205793e-02 7.92428777e-01 1.00000314e-10]
# residuals after  1 SQP_RTI iterations:
#  [1.31344880e-01 7.56713340e-03 4.27738040e-01 5.33747107e-10]
# residuals after  2 SQP_RTI iterations:
#  [2.24234037e-02 1.02106459e-03 8.55066593e-02 7.45314501e-09]
# residuals after  3 SQP_RTI iterations:
#  [6.12918945e-03 5.03927870e-05 1.66377877e-01 1.00000314e-10]
# residuals after  4 SQP_RTI iterations:
#  [2.28949904e-03 4.98962764e-05 2.90277915e-03 5.84675687e-09]
# residuals after  5 SQP_RTI iterations:
#  [5.19486294e-05 3.03954018e-08 1.27989678e-02 1.00000314e-10]
# residuals after  6 SQP_RTI iterations:
#  [1.33340075e-04 2.00682232e-07 1.52147950e-03 1.00000314e-10]
# residuals after  7 SQP_RTI iterations:
#  [1.95088487e-05 3.72052036e-09 5.05876119e-04 1.00000314e-10]
# residuals after  8 SQP_RTI iterations:
#  [5.71735692e-06 3.69802328e-10 1.53334345e-04 1.00000314e-10]
# residuals after  9 SQP_RTI iterations:
#  [1.76784081e-06 3.53518048e-11 2.08728877e-06 1.00000314e-10]
# residuals after  10 SQP_RTI iterations:
#  [1.02099630e-07 1.23789867e-14 8.06947444e-06 1.00000314e-10]
# residuals after  11 SQP_RTI iterations:
#  [9.43271949e-08 1.00613962e-13 1.22465795e-06 1.00000314e-10]
# residuals after  12 SQP_RTI iterations:
#  [1.51952148e-08 2.16493490e-15 2.03593635e-07 1.00000314e-10]

# %% [markdown]
# ## Zero-Order GP-MPC with unconditioned GP vs. conditioned GP
#
# Now we see that the training indeed paid off, and reduced uncertainty where we obtained data, i.e., we can go closer to the boundary while still being cautious.

# %%
fig, ax = base_plot(lb_theta=lb_theta)

plot_data_gpprior = EllipsoidTubeData2D(
    center_data = X_gpprior,
    ellipsoid_data = np.array(P_gpprior)
    # ellipsoid_data = None
)
add_plot_trajectory(ax, plot_data_gp, color_fun=plt.cm.Reds)
add_plot_trajectory(ax, plot_data_gpprior, color_fun=plt.cm.Blues)
